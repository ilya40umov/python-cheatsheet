# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(934)
x = np.arange(0, 30)
y1 = x ** 2 + np.random.random(30) * x * 10
y2 = x ** 2 + 0.5 * x * 10
plt.scatter(x, y1, color='blue')
plt.plot(x, y2, color='red')
plt.show()
